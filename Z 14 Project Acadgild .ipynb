# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
# %matplotlib inline
import os

from pandas import ExcelWriter
from pandas import ExcelFile
from openpyxl import load_workbook
from pandas import *
from decimal import *

# %%
df = pd.read_csv("https://raw.githubusercontent.com/jackiekazil/data-wrangling/master/data/chp3/data-text.csv")
df.head(2)
# Out:
#                           Indicator PUBLISH STATES  Year WHO region  \
# 0  Life expectancy at birth (years)      Published  1990     Europe
# 1  Life expectancy at birth (years)      Published  2000     Europe
#
#   World Bank income group  Country         Sex  Display Value  Numeric  Low  \
# 0             High-income  Andorra  Both sexes             77     77.0  NaN
# 1             High-income  Andorra  Both sexes             80     80.0  NaN
#
#    High  Comments
# 0   NaN       NaN
# 1   NaN       NaN

# %%
df.dtypes
# Out:
# Indicator                   object
# PUBLISH STATES              object
# Year                         int64
# WHO region                  object
# World Bank income group     object
# Country                     object
# Sex                         object
# Display Value                int64
# Numeric                    float64
# Low                        float64
# High                       float64
# Comments                   float64
# dtype: object

# %%
# 2
index_labels = df.index.get_values()
index_labels
# Out:
# array([   0,    1,    2, ..., 4653, 4654, 4655], dtype=int64)

# %%
df1 = pd.read_csv("https://raw.githubusercontent.com/kjam/data-wrangling-pycon/master/data/berlin_weather_oldest.csv") 
df1.head(2)
#df1.dtypes
# Out:
#              STATION         STATION_NAME      DATE  PRCP  SNWD  SNOW  TMAX  \
# 0  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310101    46 -9999 -9999 -9999
# 1  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310102   107 -9999 -9999    50
#
#    TMIN  WDFG  PGTM  ...   WT09  WT07  WT01  WT06  WT05  WT04  WT16  WT08  \
# 0   -11 -9999 -9999  ...  -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
# 1    11 -9999 -9999  ...  -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
#
#    WT18  WT03
# 0 -9999 -9999
# 1 -9999 -9999
#
# [2 rows x 21 columns]

# %%
# 2
index_labels = df1.index.get_values()
index_labels
# Out:
# array([     0,      1,      2, ..., 117205, 117206, 117207], dtype=int64)

# %%
#3 4
df_m = df.rename(columns = {'Indicator':'Indicator ID'}) # Store data in different dataframe and then use further to get the changes permanently 

df.head(2)
# Out:
#    Country  Indicator ID Publication Status  Year WHO region  \
# 0  Andorra           NaN          Published   NaN     Europe
# 1  Andorra           NaN          Published   NaN     Europe
#
#   World Bank income group         Sex  Display Value  Numeric  Low  High  \
# 0             High-income  Both sexes             77     77.0  NaN   NaN
# 1             High-income  Both sexes             80     80.0  NaN   NaN
#
#    Comments
# 0       NaN
# 1       NaN

# %%
#5
df = df.rename(columns = {'PUBLISH STATES':'Publication Status'})# Store data in different dataframe and then use further to get the changes permanently 
df.head(2)
# Out:
#                           Indicator Publication Status  Year WHO region  \
# 0  Life expectancy at birth (years)          Published  1990     Europe
# 1  Life expectancy at birth (years)          Published  2000     Europe
#
#   World Bank income group  Country         Sex  Display Value  Numeric  Low  \
# 0             High-income  Andorra  Both sexes             77     77.0  NaN
# 1             High-income  Andorra  Both sexes             80     80.0  NaN
#
#    High  Comments
# 0   NaN       NaN
# 1   NaN       NaN

# %%
#6 
df_a = df.sort_values(by=['Year'], ascending=True)
df_a.head(6)
# Out:
#                               Indicator Publication Status  Year WHO region  \
# 0      Life expectancy at birth (years)          Published  1990     Europe
# 1270   Life expectancy at birth (years)          Published  1990     Europe
# 3193   Life expectancy at birth (years)          Published  1990     Europe
# 3194   Life expectancy at birth (years)          Published  1990     Europe
# 3197  Life expectancy at age 60 (years)          Published  1990     Europe
# 1264   Life expectancy at birth (years)          Published  1990     Europe
#
#      World Bank income group              Country         Sex  Display Value  \
# 0                High-income              Andorra  Both sexes             77
# 1270             High-income              Germany        Male             72
# 3193     Lower-middle-income  Republic of Moldova        Male             65
# 3194     Lower-middle-income  Republic of Moldova  Both sexes             68
# ...

# %%
# 7
df_a = df.sort_values(by=['Year', 'Country' , 'WHO region'], ascending=True)
df_a.head(3)
# Out:
#                              Indicator Publication Status  Year  \
# 554   Life expectancy at birth (years)          Published  1990
# 555  Life expectancy at age 60 (years)          Published  1990
# 965   Life expectancy at birth (years)          Published  1990
#
#                 WHO region World Bank income group      Country         Sex  \
# 554  Eastern Mediterranean              Low-income  Afghanistan  Both sexes
# 555  Eastern Mediterranean              Low-income  Afghanistan      Female
# 965  Eastern Mediterranean              Low-income  Afghanistan        Male
#
#      Display Value  Numeric  Low  High  Comments
# 554             49     49.0  NaN   NaN       NaN
# 555             15     15.0  NaN   NaN       NaN
# 965             49     49.0  NaN   NaN       NaN

# %%
# 8 #Indexing of column name
columnsTitles = ["Country","Indicator","PUBLISH STATES","Year","WHO region","World Bank income group","Sex","Display Value","Numeric","Low","High","Comments"]
df_c = df.reindex(columns=columnsTitles)
df_c.head(2)
# Out:
#    Country                         Indicator  PUBLISH STATES  Year WHO region  \
# 0  Andorra  Life expectancy at birth (years)             NaN  1990     Europe
# 1  Andorra  Life expectancy at birth (years)             NaN  2000     Europe
#
#   World Bank income group         Sex  Display Value  Numeric  Low  High  \
# 0             High-income  Both sexes             77     77.0  NaN   NaN
# 1             High-income  Both sexes             80     80.0  NaN   NaN
#
#    Comments
# 0       NaN
# 1       NaN

# %%
# 9
import numpy as np
np.array(df['WHO region'])
# Out:
# array(['Europe', 'Europe', 'Europe', ..., 'Africa', 'Africa', 'Africa'],
#       dtype=object)

# %%
# 10
df.iloc[[11, 24, 37] , : ]
#https://thispointer.com/select-rows-columns-by-name-or-index-in-dataframe-using-loc-iloc-python-pandas/
# Out:
#                             Indicator Publication Status  Year  \
# 11   Life expectancy at birth (years)          Published  2012
# 24  Life expectancy at age 60 (years)          Published  2012
# 37  Life expectancy at age 60 (years)          Published  2012
#
#          WHO region World Bank income group            Country     Sex  \
# 11           Europe             High-income            Austria  Female
# 24  Western Pacific             High-income  Brunei Darussalam  Female
# 37           Europe             High-income             Cyprus  Female
#
#     Display Value  Numeric  Low  High  Comments
# 11             83     83.0  NaN   NaN       NaN
# 24             21     21.0  NaN   NaN       NaN
# 37             26     26.0  NaN   NaN       NaN

# %%
# 11
df.drop([5,12,23,56],axis=0, inplace= True)
df.head(13)
# Out:
#                             Indicator PUBLISH STATES  Year  \
# 0    Life expectancy at birth (years)      Published  1990
# 1    Life expectancy at birth (years)      Published  2000
# 2   Life expectancy at age 60 (years)      Published  2012
# 3   Life expectancy at age 60 (years)      Published  2000
# 4    Life expectancy at birth (years)      Published  2012
# 6   Life expectancy at age 60 (years)      Published  1990
# 7   Life expectancy at age 60 (years)      Published  2012
# 8    Life expectancy at birth (years)      Published  2012
# 9    Life expectancy at birth (years)      Published  2000
# 10   Life expectancy at birth (years)      Published  2012
# 11   Life expectancy at birth (years)      Published  2012
# 13   Life expectancy at birth (years)      Published  2012
# 14   Life expectancy at birth (years)      Published  2000
#
#                WHO region World Bank income group               Country  \
# ...
